# %%
import pandas as pd
import numpy as np

# %%
city = pd.read_csv("data/CityLocations.csv")
data = pd.read_csv("data/fatal-police-shootings-data.csv")

# %%
data.sample(5)
# Out:
#         id              name        date manner_of_death    armed   age  \
# 3061  3395             TK TK  2018-02-09            shot  vehicle   NaN
# 2641  2932      Timothy Elam  2017-09-06            shot  unarmed  42.0
# 1199  1379      Jacai Colson  2016-03-13            shot      gun  28.0
# 3038  3370  Albert E. Morton  2018-02-01            shot  vehicle  31.0
# 3134  3477     Steven Peters  2018-03-06            shot      gun  55.0
#
#      gender race         city state  signs_of_mental_illness threat_level  \
# 3061      M  NaN      Atlanta    GA                    False        other
# 2641      M    W  Los Angeles    CA                    False       attack
# 1199      M    B     Landover    MD                    False        other
# 3038      M    B   Harrisburg    PA                    False       attack
# 3134      M    W       Pueblo    CO                    False       attack
#
#              flee  body_camera
# 3061          Car        False
# ...

# %%
city.sample(5)
# Out:
#                     city         lon        lat
# 1805  West Burlington IA  -91.170253  40.820301
# 1859  Fort Washington MD  -77.012460  38.712530
# 101          Van Nuys CA -118.448729  34.186658
# 1728      Loxahatchee FL  -80.122201  26.943386
# 680      Midwest City OK  -97.396703  35.449510
