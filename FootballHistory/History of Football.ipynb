# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import matplotlib
import seaborn as sns

matplotlib.rc('font', size=20)
matplotlib.rc('axes', titlesize=20)
matplotlib.rc('axes', labelsize=20)
matplotlib.rc('xtick', labelsize=20)
matplotlib.rc('ytick', labelsize=20)
matplotlib.rc('legend', fontsize=20)
matplotlib.rc('figure', titlesize=20)

# %matplotlib inline
sns.set_style("whitegrid")
np.random.seed(42)

# %%
data = pd.read_csv("results.csv", parse_dates=['date'])
data.sample(5)
# Out:
#             date home_team   away_team  home_score  away_score  \
# 10358 1978-03-29     Spain      Norway           3           0
# 38910 2018-03-27     Spain   Argentina           6           1
# 32603 2011-06-09      Cuba      Mexico           0           5
# 1792  1935-10-06   Denmark     Finland           5           1
# 35273 2014-01-22     Chile  Costa Rica           4           0
#
#                 tournament        city  country  neutral
# 10358             Friendly       Gijón    Spain    False
# 38910             Friendly      Madrid    Spain    False
# 32603             Gold Cup   Charlotte      USA     True
# 1792   Nordic Championship  Copenhagen  Denmark    False
# 35273             Friendly    Coquimbo    Chile    False

# %%
plt.figure(figsize=(20,10))
sns.barplot(data=pd.DataFrame(data.tournament.value_counts()[:10]).reset_index(),x='tournament', y='index', orient='h')
plt.xlabel("Count")
plt.ylabel("Type of Tournament")
# Out:
# Text(0,0.5,'Type of Tournament')

# %%
plt.figure(figsize=(20,15))
sns.countplot(data=data, x='tournament')
data.tournament.value_counts()
# Out:
# Friendly                                16412
# FIFA World Cup qualification             7100
# UEFA Euro qualification                  2332
# African Cup of Nations qualification     1558
# FIFA World Cup                            836
# Copa América                              787
# AFC Asian Cup qualification               724
# African Cup of Nations                    638
# CECAFA Cup                                620
# CFU Caribbean Cup qualification           606
# Merdeka Tournament                        504
# British Championship                      501
# Gulf Cup                                  333
# AFC Asian Cup                             319
# Gold Cup                                  296
# UEFA Euro                                 286
# Nordic Championship                       283
# AFF Championship                          267
# COSAFA Cup                                262
# CFU Caribbean Cup                         251
# Amílcar Cabral Cup                        235
# King's Cup                                234
# South Pacific Games                       198
# African Nations Championship              184
# UNCAF Cup                                 164
# Korea Cup                                 159
# Confederations Cup                        140
# International Cup                         127
# SAFF Cup                                  124
# CCCF Championship                         123
#                                         ...
# Copa del Pacífico                          19
# Copa Rio Branco                            18
# Simba Tournament                           17
# Copa Carlos Dittborn                       16
# Copa Juan Pinto Durán                      16
# Copa Oswaldo Cruz                          16
# Copa Premio Honor Uruguayo                 15
# UNIFFAC Cup                                15
# Dunhill Cup                                15
# Millennium Cup                             15
# Nile Basin Tournament                      14
# GaNEFo                                     14
# Copa Artigas                               13
# Jordan International Tournament            13
# King Hassan II Tournament                  12
# Copa Premio Honor Argentino                12
# Atlantic Cup                               11
# Rous Cup                                   11
# SKN Football Festival                      11
# Tournoi de France                          10
# Copa Bernardo O'Higgins                    10
# VFF Cup                                     9
# UAFA Cup qualification                      9
# NAFU Championship                           7
# Mundialito                                  7
# Nations Cup                                 6
# Copa Félix Bogado                           6
# Copa Ramón Castilla                         6
# Dragon Cup                                  4
# OSN Cup                                     4
# Name: tournament, Length: 95, dtype: int64
