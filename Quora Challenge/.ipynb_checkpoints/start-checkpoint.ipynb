# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('darkgrid')
# %matplotlib inline
matplotlib.rc('font', size=20)
matplotlib.rc('axes', titlesize=20)
matplotlib.rc('axes', labelsize=20)
matplotlib.rc('xtick', labelsize=20)
matplotlib.rc('ytick', labelsize=20)
matplotlib.rc('legend', fontsize=20)
matplotlib.rc('figure', titlesize=20)

# %%
data = pd.read_csv("/Users/sominwadhwa/Work/Kaggle_Data/Quora/train.csv")
data.ix[np.random.choice(data.index,2 10)]
# Out:
#             id    qid1    qid2  \
# 350559  350559  479311  479312
# 376939  376939  175441  508151
# 147045  147045  232144  232145
# 49325    49325   87799   87800
# 70819    70819  121979  121980
# 276743  276743  170671  278329
# 263716  263716  380307  277232
# 359110  359110  488713  488714
# 198556  198556  299807  299808
# 223118  223118  330862  330863
#
#                                                 question1  \
# 350559  Promotion at IT MNC India : I am a very good p...
# 376939  How do liberals feel about Trump saving 10,000...
# 147045  Is the density of canola oil affected by press...
# 49325         How do I start learning about stock market?
# 70819         What shall I do when everything goes wrong?
# 276743                Why Do Olympians Bite Their Medals?
# 263716  What are some simple math tricks that you can ...
# 359110    How rare is the mythical 10x software engineer?
# 198556  Could someone tell of a James Ronsey (misspell...
# 223118  What are the best areas to invest with 100K in...
#
#                                                 question2  is_duplicate
# 350559  I am currently working as a performance engine...             0
# 376939  What major misconceptions do conservatives hav...             0
# 147045  How can the density of canola oil affect its q...             0
# 49325              How do we start learning stock market?             1
# 70819            What do I do when everything goes wrong?             1
# 276743     Why do olympians bite medal after they win it?             1
# 263716    What are some useful math tricks in daily life?             1
# 359110  What's a first second and third level domain n...             0
# 198556  What are the best instructions about fin heat ...             0
# 223118  How should I invest 100k-150k at age 30 living...             0

# %%
data.shape
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 404290 entries, 0 to 404289
# Data columns (total 6 columns):
# id              404290 non-null int64
# qid1            404290 non-null int64
# qid2            404290 non-null int64
# question1       404290 non-null object
# question2       404288 non-null object
# is_duplicate    404290 non-null int64
# dtypes: int64(4), object(2)
# memory usage: 18.5+ MB

# %%
plt.figure(figsize=(20,10))
data_by_count = data.groupby('is_duplicate', as_index=False).id.count()
sns.barplot(data=data_by_count, x='is_duplicate', y='id', alpha=0.6)
plt.xlabel("Duplicate")
plt.ylabel("Count")

# %%
from collections import Counter
import operator
import nltk
from nltk.corpus import stopwords
from sklearn.metrics import log_loss
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
import multiprocessing
import difflib
from sklearn.cross_validation import train_test_split
import xgboost as xgb

# %% [markdown]
# ### Approach
# 0. Do simple Cosine/Jaccard similarity check w/o any semantic analysis whatsoever
# 1. Check for similarities in Test/Training Data
# 2. Create a list of all questions under one list
# 3. Do EDA - Word/Char Count Hist (labelling-dup or not), correlation, semantic analysis
# 4. Improvise with TF-IDF
# 5. Test different predictive models- Logistic, XGB etc with supporting ROC/P-R curves

# %%
stop = stopwords.words('english')

# %%
data = data.dropna()
data['question1'] = data['question1'].apply(lambda x: x.rstrip('?'))
data['question2'] = data['question2'].apply(lambda x: x.rstrip('?'))
data['question1'] = data['question1'].str.lower().str.split()
data['question2'] = data['question2'].str.lower().str.split()
data['question1'] = data['question1'].apply(lambda x: [item for item in x if item not in stop])
data['question2'] = data['question2'].apply(lambda x: [item for item in x if item not in stop])

# %%
data.ix[np.random.choice(data.index, 10)]
# Out:
#             id    qid1    qid2  \
# 45320    45320   81235   81236
# 363592  363592  493599  493600
# 75769    75769  129615  129616
# 249159  249159  362717  362718
# 227779  227779  336697   18180
# 305396  305396  428801  428802
# 386073  386073   11034   68603
# 16570    16570   31582   31583
# 129265  129265  207688  207689
# 339851  339851  467534  116615
#
#                                                 question1  \
# 45320   [following, professions, average, financially,...
# 363592       [diet, us, president, restricted, protocols]
# 75769                      [hierarchy, mckinsey, company]
# 249159                [best, chess, tutorials, beginners]
# 227779                             [sell, sarees, online]
# 305396           [many, countries, national, flag, eagle]
# 386073                       [solution, kashmir, problem]
# 16570       [play, game, files, downloaded, ocean, games]
# 129265   [tall, empire, state, building, new, york, city]
# 339851  [best, photograph, government, corruption, india]
#
#                                                 question2  is_duplicate
# 45320   [profession, better, chartered, accountant, so...             0
# 363592                            [us, presidents, alive]             0
# 75769                   [hierarchy, mckinsey, &, company]             1
# 249159             [best, books, beginner, chess, player]             0
# 227779                             [start, online, store]             0
# 305396            [time, national, flags, get, abolished]             0
# 386073            [think, best, solution, kashmir, issue]             1
# 16570                 [get, old, snapchat, stories, back]             0
# 129265                              [tall, empire, state]             1
# 339851         [best, photograph, government, corruption]             0

# %%
data['Common'] = data.apply(lambda row: len(list(set(row['question1']).intersection(row['question2']))), axis=1)
data['Average'] = data.apply(lambda row: 0.5*(len(row['question1'])+len(row['question2'])), axis=1)
data['Percentage'] = data.apply(lambda row: row['Common']*100.0/(row['Average']+1), axis=1)

# %%
data.ix[np.random.choice(data.index,10)]
# Out:
#             id    qid1    qid2  \
# 107688  107688  177110  177111
# 291974  291974     160   12132
# 101961  101961  168793  168794
# 307366  307366  431035  431036
# 264594  264594   82929  381398
# 46786    46786   83631   83632
# 137545  137545   86342  137719
# 206125  206125   23375  309462
# 110149  110149    4125  180657
# 340376  340376  291038   61542
#
#                                                 question1  \
# 107688            [best, money, making, app, click, call]
# 291974           [what's, purpose, life?, life, actually]
# 101961                  [best, laptop, rs, 150000, india]
# 307366            [strongest, power, world, around, 1750]
# 264594  [harm, taking, antibiotics, haphazardly, 2, we...
# 46786   [people, furious, eating, dogs, beef,, pork,, ...
# 137545                                [get, better, math]
# 206125      [references, pokemon, red, blue, pokemon, xy]
# 110149  [epic,, funniest, farewell, emails, ever, sent...
# 340376                          [causes, cure, diabetics]
#
#                                                 question2  is_duplicate  \
# 107688                         [app, best, making, money]             0
# 291974                         [according, purpose, life]             1
# 101961          [best, laptop, buy, rs., 1,00,000, india]             0
# 307366                           [strongest, wall, world]             0
# 264594  [japanese, girlfriend, 2.5, years, working, va...             0
# 46786   [many, people, eating, dog, meat,, eating, por...             1
# 137545                               [become, good, math]             1
# 206125  [what's, biggest, mystery/secret, pokémon, red...             0
# 110149      [make, farewell, speech, personal, emotional]             0
# 340376                                 [causes, diabetes]             1
#
#         Common  Average  Percentage
# 107688       4      5.0   66.666667
# 291974       2      4.0   40.000000
# 101961       3      5.5   46.153846
# 307366       2      4.0   40.000000
# 264594       2     15.5   12.121212
# 46786        5      8.0   55.555556
# 137545       1      3.0   25.000000
# 206125       0      5.5    0.000000
# 110149       1      7.0   12.500000
# 340376       1      2.5   28.571429

# %% [markdown]
# ## Studying Cosine Similarity
