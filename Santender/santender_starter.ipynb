# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style("whitegrid")

# %matplotlib inline

# %%
train = pd.read_csv("data/train.csv")
#test = pd.read_csv("data/test.csv")
#sample = pd.read_csv("data/sample_submission.csv")

# %%
train.shape
# Out:
# (4459, 4993)

# %%
from fastai.column_data import *
from fastai.structured import *

# %%
train.describe()
# Out:
#              target     48df886f9     0deb4b6a8     34b15f335     a8cb14b00  \
# count  4.459000e+03  4.459000e+03  4.459000e+03  4.459000e+03  4.459000e+03
# mean   5.944923e+06  1.465493e+04  1.390895e+03  2.672245e+04  4.530164e+03
# std    8.234312e+06  3.893298e+05  6.428302e+04  5.699652e+05  2.359124e+05
# min    3.000000e+04  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 25%    6.000000e+05  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 50%    2.260000e+06  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 75%    8.000000e+06  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# max    4.000000e+07  2.000000e+07  4.000000e+06  2.000000e+07  1.480000e+07
#
#           2f0771a37     30347e683     d08d1fbe3     6ee66e115     20aa07010  \
# count  4.459000e+03  4.459000e+03  4.459000e+03  4.459000e+03  4.459000e+03
# mean   2.640996e+04  3.070811e+04  1.686522e+04  4.669208e+03  2.569407e+06
# ...

# %%
X = train.drop(['ID','target'], axis=1)
y = train['target']
yl = np.log(y)

# %%
val_idx = get_cv_idxs(train.shape[0], val_pct=0.25)

# %%
def inv_y(y_pred): return np.exp(y_pred)

def lb_score(y_pred, target):
    y_pred = inv_y(y_pred)
    lp = np.log(y_pred+1)
    la = np.log(target+1)
    return np.sqrt(np.square(lp - la).mean())

max_log_y = np.max(yl)
y_range = (0, max_log_y*1.2)

# %%
md = ColumnarModelData.from_data_frame("data/", val_idx, X, yl.astype(np.float32),
                                      test_df=test, bs=128, cat_flds=[])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-25-62cc390185be> in <module>()
#       1 md = ColumnarModelData.from_data_frame("data/", val_idx, X, yl.astype(np.float32),
# ----> 2                                       test_df=test, bs=128, cat_flds=[])
#
# ~/.venv/lib/python3.6/site-packages/fastai/column_data.py in from_data_frame(cls, path, val_idxs, df, y, cat_flds, bs, is_reg, is_multi, test_df)
#      71     def from_data_frame(cls, path, val_idxs, df, y, cat_flds, bs, is_reg=True, is_multi=False, test_df=None):
#      72         ((val_df, trn_df), (val_y, trn_y)) = split_by_idx(val_idxs, df, y)
# ---> 73         return cls.from_data_frames(path, trn_df, val_df, trn_y, val_y, cat_flds, bs, is_reg, is_multi, test_df=test_df)
#      74
#      75     def get_learner(self, emb_szs, n_cont, emb_drop, out_sz, szs, drops,
#
# ...

# %%
'fffbe2f6f' in list(X.columns)
# Out:
# False
